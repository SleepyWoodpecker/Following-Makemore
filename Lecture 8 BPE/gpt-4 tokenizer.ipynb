# %% [markdown]
# Cannot wait to be building my own GPT tokenizer!

# %%
class BasicTokenizer:
    def _get_pair_rankings(self, text_bytes):
        """count the occurances for each pair in the input"""
         # generate a list of the most common byte-pairs
        encountered_pairs = {}
        for pair in zip(text_bytes, text_bytes[1:]): # neat way of iterating through the pairs
            encountered_pairs[pair] = encountered_pairs.get(pair, 0) + 1

        # sort the pairs
        encountered_pairs = list(sorted(encountered_pairs.items(), key=lambda x: x[1], reverse=True))
        return encountered_pairs
    

    def _merge_bp(self, text_bytes, encountered_pairs, next_token, verbose):
        """perform a merge on the most frequently occuring byte pair"""
        merges = {}

         # choose the pair that has the highest count and do compression
        top_pair_and_count = encountered_pairs[0]
        skip_next = False
        new_sequence = []

        for pair in zip(text_bytes, text_bytes[1:]):
            if skip_next:
                skip_next = False
                continue

            if pair == top_pair_and_count[0]:
                new_sequence.append(next_token)
                # since 2 tokens were compressed into 1, skip the next token
                skip_next = True

            else:
                new_sequence.append(pair[0])

        if verbose:
            print(f"Merged {top_pair_and_count[0]} into {next_token}.")

        merges[next_token] = top_pair_and_count[0]
        
        # account for the last token that was not zipped 
        new_sequence = new_sequence + [text_bytes[-1]] if not skip_next else []

        return new_sequence, merges

    def train(self, text, vocab_size, verbose=False):
        """Train the tokenizer on your own text sequence"""
        # start the tokenizer by changing the code to utf-8 encodings
        text_bytes = list(text.encode("utf-8"))
        merges = {}
        
        next_token = 256

        while next_token < vocab_size:
            encountered_pairs = self._get_pair_rankings(text_bytes)
            # important: after each round of encoding, update the series of text bytes and record the bpe that occured
            text_bytes, new_merge = self._merge_bp(text_bytes, encountered_pairs, next_token, verbose)
            merges = {**merges, **new_merge}
            next_token += 1
    
        return text_bytes

# %%
tokenizer = BasicTokenizer()
training_set = open("../taylorswift.txt", "r", encoding="utf-8").read()

r = tokenizer.train(training_set, 500, True)
# Out:
# Merged (101, 32) into 256.
# Merged (44, 32) into 257.
# Merged (100, 32) into 258.
# Merged (46, 32) into 259.
# Merged (114, 32) into 260.
# Merged (50, 48) into 261.
# Merged (115, 32) into 262.
# Merged (105, 110) into 263.
# Merged (111, 110) into 264.
# Merged (114, 105) into 265.
# Merged (116, 32) into 266.
# Merged (116, 104) into 267.
# Merged (101, 258) into 268.
# Merged (257, 261) into 269.
# Merged (97, 110) into 270.
# Merged (97, 114) into 271.
# Merged (101, 260) into 272.
# Merged (121, 32) into 273.
# Merged (97, 108) into 274.
# Merged (267, 256) into 275.
# Merged (118, 268) into 276.
# Merged (119, 105) into 277.
# Merged (101, 114) into 278.
# Merged (264, 32) into 279.
# Merged (277, 102) into 280.
# Merged (82, 101) into 281.
# Merged (83, 280) into 282.
# Merged (111, 260) into 283.
# Merged (99, 104) into 284.
# Merged (269, 49) into 285.
# Merged (111, 109) into 286.
# Merged (98, 272) into 287.
# Merged (32, 275) into 288.
# Merged (97, 121) into 289.
# Merged (101, 110) into 290.
# Merged (111, 114) into 291.
# Merged (274, 32) into 292.
# Merged (101, 109) into 293.
# Merged (46, 10) into 294.
# Merged (265, 101) into 295.
# Merged (263, 103) into 296.
# Merged (269, 50) into 297.
# Merged (116, 105) into 298.
# Merged (289, 108) into 299.
# Merged (34, 259) into 300.
# Merged (108, 108) into 301.
# Merged (84, 299) into 302.
# Merged (116, 295) into 303.
# Merged (294, 32) into 304.
# Merged (116, 111) into 305.
# Merged (259, 281) into 306.
# Merged (306, 303) into 307.
# Merged (307, 276) into 308.
# Merged (302, 283) into 309.
# Merged (101, 115) into 310.
# Merged (309, 282) into 311.
# Merged (117, 115) into 312.
# Merged (114, 286) into 313.
# Merged (293, 287) into 314.
# Merged (41, 259) into 315.
# Merged (65, 114) into 316.
# Merged (102, 313) into 317.
# Merged (315, 34) into 318.
# Merged (270, 258) into 319.
# Merged (114, 101) into 320.
# Merged (111, 117) into 321.
# Merged (111, 265) into 322.
# Merged (111, 102) into 323.
# Merged (103, 263) into 324.
# Merged (296, 32) into 325.
# Merged (284, 105) into 326.
# Merged (93, 32) into 327.
# Merged (324, 292) into 328.
# Merged (317, 288) into 329.
# Merged (322, 328) into 330.
# Merged (104, 256) into 331.
# Merged (316, 326) into 332.
# Merged (332, 276) into 333.
# Merged (329, 330) into 334.
# Merged (333, 334) into 335.
# Merged (335, 279) into 336.
# Merged (259, 336) into 337.
# Merged (97, 32) into 338.
# Merged (115, 116) into 339.
# Merged (105, 99) into 340.
# Merged (46, 91) into 341.
# Merged (101, 99) into 342.
# Merged (105, 301) into 343.
# Merged (39, 262) into 344.
# Merged (311, 266) into 345.
# Merged (111, 118) into 346.
# Merged (97, 116) into 347.
# Merged (97, 262) into 348.
# Merged (101, 262) into 349.
# Merged (74, 117) into 350.
# Merged (323, 32) into 351.
# Merged (305, 32) into 352.
# Merged (117, 109) into 353.
# Merged (84, 331) into 354.
# Merged (271, 100) into 355.
# Merged (263, 32) into 356.
# Merged (270, 32) into 357.
# Merged (101, 108) into 358.
# Merged (297, 51) into 359.
# Merged (271, 273) into 360.
# Merged (267, 32) into 361.
# Merged (97, 109) into 362.
# Merged (108, 273) into 363.
# Merged (111, 112) into 364.
# Merged (311, 116) into 365.
# Merged (116, 114) into 366.
# Merged (105, 115) into 367.
# Merged (104, 272) into 368.
# Merged (111, 32) into 369.
# Merged (117, 360) into 370.
# Merged (78, 346) into 371.
# Merged (312, 340) into 372.
# Merged (371, 314) into 373.
# Merged (101, 119) into 374.
# Merged (97, 266) into 375.
# Merged (108, 32) into 376.
# Merged (58, 32) into 377.
# Merged (98, 111) into 378.
# Merged (282, 266) into 379.
# Merged (68, 342) into 380.
# Merged (105, 116) into 381.
# Merged (105, 103) into 382.
# Merged (66, 343) into 383.
# Merged (49, 48) into 384.
# Merged (97, 115) into 385.
# Merged (264, 103) into 386.
# Merged (79, 99) into 387.
# Merged (97, 298) into 388.
# Merged (83, 116) into 389.
# Merged (387, 305) into 390.
# Merged (390, 287) into 391.
# Merged (97, 99) into 392.
# Merged (111, 119) into 393.
# Merged (380, 314) into 394.
# Merged (383, 378) into 395.
# Merged (97, 100) into 396.
# Merged (108, 101) into 397.
# Merged (117, 114) into 398.
# Merged (102, 283) into 399.
# Merged (32, 40) into 400.
# Merged (297, 50) into 401.
# Merged (117, 103) into 402.
# Merged (284, 32) into 403.
# Merged (115, 266) into 404.
# Merged (321, 110) into 405.
# Merged (98, 353) into 406.
# Merged (111, 108) into 407.
# Merged (312, 266) into 408.
# Merged (101, 98) into 409.
# Merged (77, 97) into 410.
# Merged (350, 363) into 411.
# Merged (318, 345) into 412.
# Merged (107, 32) into 413.
# Merged (278, 115) into 414.
# Merged (93, 91) into 415.
# Merged (65, 402) into 416.
# Merged (416, 408) into 417.
# Merged (105, 100) into 418.
# Merged (297, 49) into 419.
# Merged (109, 101) into 420.
# Merged (101, 112) into 421.
# Merged (261, 49) into 422.
# Merged (50, 51) into 423.
# Merged (285, 50) into 424.
# Merged (101, 271) into 425.
# Merged (269, 261) into 426.
# Merged (73, 110) into 427.
# Merged (102, 105) into 428.
# Merged (110, 256) into 429.
# Merged (395, 355) into 430.
# Merged (265, 116) into 431.
# Merged (104, 105) into 432.
# Merged (372, 32) into 433.
# Merged (304, 34) into 434.
# Merged (78, 374) into 435.
# Merged (100, 105) into 436.
# Merged (65, 112) into 437.
# Merged (285, 57) into 438.
# Merged (114, 111) into 439.
# Merged (39, 32) into 440.
# Merged (115, 257) into 441.
# Merged (350, 429) into 442.
# Merged (323, 288) into 443.
# Merged (99, 291) into 444.
# Merged (50, 49) into 445.
# Merged (49, 57) into 446.
# Merged (105, 109) into 447.
# Merged (290, 32) into 448.
# Merged (409, 114) into 449.
# Merged (290, 116) into 450.
# Merged (111, 301) into 451.
# Merged (77, 271) into 452.
# Merged (265, 99) into 453.
# Merged (277, 361) into 454.
# Merged (44, 91) into 455.
# Merged (70, 449) into 456.
# Merged (456, 370) into 457.
# Merged (365, 344) into 458.
# Merged (300, 430) into 459.
# Merged (101, 97) into 460.
# Merged (285, 54) into 461.
# Merged (421, 116) into 462.
# Merged (410, 273) into 463.
# Merged (285, 53) into 464.
# Merged (437, 265) into 465.
# Merged (465, 376) into 466.
# Merged (108, 256) into 467.
# Merged (65, 119) into 468.
# Merged (388, 264) into 469.
# Merged (83, 462) into 470.
# Merged (470, 314) into 471.
# Merged (114, 97) into 472.
# Merged (274, 406) into 473.
# Merged (67, 104) into 474.
# Merged (118, 256) into 475.
# Merged (310, 266) into 476.
# Merged (74, 270) into 477.
# Merged (50, 50) into 478.
# Merged (477, 370) into 479.
# Merged (405, 366) into 480.
# Merged (382, 104) into 481.
# Merged (300, 354) into 482.
# Merged (359, 304) into 483.
# Merged (49, 51) into 484.
# Merged (65, 108) into 485.
# Merged (101, 116) into 486.
# Merged (310, 115) into 487.
# Merged (452, 403) into 488.
# Merged (117, 116) into 489.
# Merged (119, 431) into 490.
# Merged (108, 111) into 491.
# Merged (115, 386) into 492.
# Merged (226, 128) into 493.
# Merged (271, 258) into 494.
# Merged (48, 32) into 495.
# Merged (117, 108) into 496.
# Merged (50, 52) into 497.
# Merged (105, 262) into 498.
# Merged (298, 99) into 499.
